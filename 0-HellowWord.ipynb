# %% [markdown]
# # 0. Hellow World
# tensorflow 第一个程序

# %%
import tensorflow as tf

# %%
A = tf.constant([[1,2],[3,4]])
B = tf.constant([[5,6],[7,8]])
c = tf.matmul(A,B)
print(c)
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)
